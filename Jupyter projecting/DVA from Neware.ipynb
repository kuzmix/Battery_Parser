# %%
Нет

# %% [markdown]
# Создан 06.12.24 для потоковой обработки DVA с neware.
# Планируется
# 1. импорт файла xls
# 2. извлечение данных, составление значений dQ/dV
# 3. Экспорт данных

# %%
import pandas as pd

import battery_parser as bp

# %% [markdown]
# Экспорт всех excel-файлов

# %%
fp = r'D:\!Science\Analysis\Electrochem\2024 Na-ion\final neware\2024-12-05 DVA'
files = bp.list_files(fp, 'xlsx')
files = [pd.read_excel(i, None, engine="openpyxl") for i in files]
# Out:
# D:\Python\Projects\Battery_Parser\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# D:\Python\Projects\Battery_Parser\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# D:\Python\Projects\Battery_Parser\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# D:\Python\Projects\Battery_Parser\venv\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
files[0]
# Out:
# {'unit':   20241202205008-SA03-dva-1-1-Na-ion 18650 GITT.xlsx Unnamed: 1  \
#  0                                             device         89
#  1                                         Start time        NaN
#  2                                      NDA file path        NaN
#  3                                 List of unit plans        NaN
#  4                                               Time    Current
#  5                                           hh:mm:ss          A
#
#              Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5           Unnamed: 6  \
#  0                    1          1        NaN        NaN                  NaN
#  1  2024-12-02 20:50:08        NaN   End time        NaN  2024-12-05 20:03:37
#  2                  NaN        NaN        NaN        NaN                  NaN
#  3                  NaN        NaN        NaN        NaN                  NaN
#  4              Voltage   Capacity     Energy      Power  Internal resistance
# ...
